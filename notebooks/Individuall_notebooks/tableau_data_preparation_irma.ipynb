# %%
import pandas as pd

# === Vanguard KPI Summary for Tableau ===
data = [
    ["Completion Rate", "Control", 49.97, "%", "Percentage of Control group users who completed the process"],
    ["Completion Rate", "Test", 52.57, "%", "Percentage of Test group users who completed the process"],
    ["Strict Completion Rate", "Control", 49.78, "%", "Percentage of Control group users who followed strict funnel order and completed it"],
    ["Strict Completion Rate", "Test", 52.43, "%", "Percentage of Test group users who followed strict funnel order and completed it"],
    ["Completion Rate Lift", "Test vs Control", 2.65, "pp", "Improvement in completion rate for Test compared to Control"],
    ["Step_Back_Errors", "Control", 5521, "Count", "Total backward step errors in Control group"],
    ["Step_Back_Errors", "Test", 8138, "Count", "Total backward step errors in Test group"],
    ["Step_Repeat_Errors", "Control", 7298, "Count", "Total repeated step errors in Control group"],
    ["Step_Repeat_Errors", "Test", 11139, "Count", "Total repeated step errors in Test group"],
    ["Mean_Step_Time_start", "Control", 57.46, "Seconds", "Average duration at start step for Control group"],
    ["Mean_Step_Time_start", "Test", 51.39, "Seconds", "Average duration at start step for Test group"],
    ["Mean_Step_Time_step_1", "Control", 46.56, "Seconds", "Average duration at Step 1 for Control group"],
    ["Mean_Step_Time_step_1", "Test", 56.53, "Seconds", "Average duration at Step 1 for Test group"],
    ["Mean_Step_Time_step_2", "Control", 94.35, "Seconds", "Average duration at Step 2 for Control group"],
    ["Mean_Step_Time_step_2", "Test", 92.32, "Seconds", "Average duration at Step 2 for Test group"],
    ["Mean_Step_Time_step_3", "Control", 129.58, "Seconds", "Average duration at Step 3 for Control group"],
    ["Mean_Step_Time_step_3", "Test", 111.67, "Seconds", "Average duration at Step 3 for Test group"]
]

df_kpi = pd.DataFrame(data, columns=["Metric", "Variation", "Value", "Unit", "Description"])

# Save to CSV
output_path = "../../data/clean_data_txt/vanguard_kpi_summary_for_tableau_irma.csv"
df_kpi.to_csv(output_path, index=False)
print(f"✅ File saved successfully at: {output_path}")
df_kpi.head()
# Out:
# ✅ File saved successfully at: ../../data/clean_data_txt/vanguard_kpi_summary_for_tableau_irma.csv
#                    Metric        Variation  Value Unit  \
# 0         Completion Rate          Control  49.97    %
# 1         Completion Rate             Test  52.57    %
# 2  Strict Completion Rate          Control  49.78    %
# 3  Strict Completion Rate             Test  52.43    %
# 4    Completion Rate Lift  Test vs Control   2.65   pp
#
#                                          Description
# 0  Percentage of Control group users who complete...
# 1  Percentage of Test group users who completed t...
# 2  Percentage of Control group users who followed...
# 3  Percentage of Test group users who followed st...
# 4  Improvement in completion rate for Test compar...

# %%
import pandas as pd

# === 1. Load your existing CSV ===
path = "../../data/clean_data_txt/vanguard_kpi_summary_for_tableau_irma.csv"
df = pd.read_csv(path)

# === 2. Filter step-time metrics ===
step_metrics = [
    'Mean_Step_Time_start',
    'Mean_Step_Time_step_1',
    'Mean_Step_Time_step_2',
    'Mean_Step_Time_step_3'
]
df_steps = df[df['Metric'].isin(step_metrics)]

# === 3. Calculate the total mean completion time per Variation ===
mean_completion = (
    df_steps.groupby('Variation', as_index=False)['Value'].sum()
)
mean_completion['Metric'] = 'Mean_Completion_Time'
mean_completion['Unit'] = 'Seconds'
mean_completion['Description'] = 'Total average time (sum of steps) to complete the process'

# === Redondear a 2 decimales ===
mean_completion['Value'] = mean_completion['Value'].round(2)

# === 4. Reorder columns to match your original CSV ===
df_final = pd.concat([df, mean_completion[df.columns]], ignore_index=True)

# === 5. Save new version ===
output_path = "../../data/clean_data_txt/vanguard_kpi_summary_for_tableau_irma_v2.csv"
df_final.to_csv(output_path, index=False)

print("✅ File saved successfully!")
print(df_final.tail(6))
# Out:
# ✅ File saved successfully!
#                    Metric Variation   Value     Unit  \
# 13  Mean_Step_Time_step_2   Control   94.35  Seconds
# 14  Mean_Step_Time_step_2      Test   92.32  Seconds
# 15  Mean_Step_Time_step_3   Control  129.58  Seconds
# 16  Mean_Step_Time_step_3      Test  111.67  Seconds
# 17   Mean_Completion_Time   Control  327.95  Seconds
# 18   Mean_Completion_Time      Test  311.91  Seconds
#
#                                           Description
# 13       Average duration at Step 2 for Control group
# 14          Average duration at Step 2 for Test group
# 15       Average duration at Step 3 for Control group
# 16          Average duration at Step 3 for Test group
# 17  Total average time (sum of steps) to complete ...
# 18  Total average time (sum of steps) to complete ...

# %%
import pandas as pd

# === Load existing KPI summary ===
path = "../../data/clean_data_txt/vanguard_kpi_summary_for_tableau_irma_1.csv"
df = pd.read_csv(path)

# === Add new metrics ===
new_metrics = [
    ["Calls_6M_Mean", "Control", 2.1, "count", "Average number of calls in 6 months per user (Control group)"],
    ["Calls_6M_Mean", "Test", 2.4, "count", "Average number of calls in 6 months per user (Test group)"],
    ["Logons_6M_Mean", "Control", 5.3, "count", "Average number of logons in 6 months per user (Control group)"],
    ["Logons_6M_Mean", "Test", 6.0, "count", "Average number of logons in 6 months per user (Test group)"],
    ["Strict_Lift_CI", "Test vs Control", "1.78 – 3.44", "%", "95% confidence interval for the strict completion rate lift"],
    ["p_value", "Test vs Control", 0.0015, "", "Two-tailed p-value from proportion test confirming statistical significance"]
]
# === Display Vanguard KPI Summary nicely aligned ===
path = "../../data/clean_data_txt/vanguard_kpi_summary_for_tableau_irma_1.csv"
df = pd.read_csv(path)

# Set visual display options (does not modify the file)
pd.set_option("display.colheader_justify", "left")   # left-align headers
pd.set_option("display.width", None)                 # prevents line wrapping
pd.set_option("display.max_colwidth", None)          # shows full text in Description column

# Show nicely aligned preview
print("📋 Vanguard KPI Summary Preview (clean and aligned):\n")
display(
    df.style
    .set_properties(**{'text-align': 'left'})  # left-align all text
    .hide(axis='index')                        # hide numeric index
)
df_new = pd.DataFrame(new_metrics, columns=["Metric", "Variation", "Value", "Unit", "Description"])

# === Append new rows and save ===
df_final = pd.concat([df, df_new], ignore_index=True)
df_final.to_csv(path, index=False)

print(f"✅ File updated successfully at: {path}")
print(f"Total metrics now: {len(df_final)} rows")
df_final.tail(8)
# Out:
# 📋 Vanguard KPI Summary Preview (clean and aligned):
# <style type="text/css">
# #T_8dbcd_row0_col0, #T_8dbcd_row0_col1, #T_8dbcd_row0_col2, #T_8dbcd_row0_col3, #T_8dbcd_row0_col4, #T_8dbcd_row1_col0, #T_8dbcd_row1_col1, #T_8dbcd_row1_col2, #T_8dbcd_row1_col3, #T_8dbcd_row1_col4, #T_8dbcd_row2_col0, #T_8dbcd_row2_col1, #T_8dbcd_row2_col2, #T_8dbcd_row2_col3, #T_8dbcd_row2_col4, #T_8dbcd_row3_col0, #T_8dbcd_row3_col1, #T_8dbcd_row3_col2, #T_8dbcd_row3_col3, #T_8dbcd_row3_col4, #T_8dbcd_row4_col0, #T_8dbcd_row4_col1, #T_8dbcd_row4_col2, #T_8dbcd_row4_col3, #T_8dbcd_row4_col4, #T_8dbcd_row5_col0, #T_8dbcd_row5_col1, #T_8dbcd_row5_col2, #T_8dbcd_row5_col3, #T_8dbcd_row5_col4, #T_8dbcd_row6_col0, #T_8dbcd_row6_col1, #T_8dbcd_row6_col2, #T_8dbcd_row6_col3, #T_8dbcd_row6_col4, #T_8dbcd_row7_col0, #T_8dbcd_row7_col1, #T_8dbcd_row7_col2, #T_8dbcd_row7_col3, #T_8dbcd_row7_col4, #T_8dbcd_row8_col0, #T_8dbcd_row8_col1, #T_8dbcd_row8_col2, #T_8dbcd_row8_col3, #T_8dbcd_row8_col4, #T_8dbcd_row9_col0, #T_8dbcd_row9_col1, #T_8dbcd_row9_col2, #T_8dbcd_row9_col3, #T_8dbcd_row9_col4, #T_8dbcd_row10_col0, #T_8dbcd_row10_col1, #T_8dbcd_row10_col2, #T_8dbcd_row10_col3, #T_8dbcd_row10_col4, #T_8dbcd_row11_col0, #T_8dbcd_row11_col1, #T_8dbcd_row11_col2, #T_8dbcd_row11_col3, #T_8dbcd_row11_col4, #T_8dbcd_row12_col0, #T_8dbcd_row12_col1, #T_8dbcd_row12_col2, #T_8dbcd_row12_col3, #T_8dbcd_row12_col4, #T_8dbcd_row13_col0, #T_8dbcd_row13_col1, #T_8dbcd_row13_col2, #T_8dbcd_row13_col3, #T_8dbcd_row13_col4, #T_8dbcd_row14_col0, #T_8dbcd_row14_col1, #T_8dbcd_row14_col2, #T_8dbcd_row14_col3, #T_8dbcd_row14_col4, #T_8dbcd_row15_col0, #T_8dbcd_row15_col1, #T_8dbcd_row15_col2, #T_8dbcd_row15_col3, #T_8dbcd_row15_col4, #T_8dbcd_row16_col0, #T_8dbcd_row16_col1, #T_8dbcd_row16_col2, #T_8dbcd_row16_col3, #T_8dbcd_row16_col4, #T_8dbcd_row17_col0, #T_8dbcd_row17_col1, #T_8dbcd_row17_col2, #T_8dbcd_row17_col3, #T_8dbcd_row17_col4, #T_8dbcd_row18_col0, #T_8dbcd_row18_col1, #T_8dbcd_row18_col2, #T_8dbcd_row18_col3, #T_8dbcd_row18_col4, #T_8dbcd_row19_col0, #T_8dbcd_row19_col1, #T_8dbcd_row19_col2, #T_8dbcd_row19_col3, #T_8dbcd_row19_col4, #T_8dbcd_row20_col0, #T_8dbcd_row20_col1, #T_8dbcd_row20_col2, #T_8dbcd_row20_col3, #T_8dbcd_row20_col4, #T_8dbcd_row21_col0, #T_8dbcd_row21_col1, #T_8dbcd_row21_col2, #T_8dbcd_row21_col3, #T_8dbcd_row21_col4, #T_8dbcd_row22_col0, #T_8dbcd_row22_col1, #T_8dbcd_row22_col2, #T_8dbcd_row22_col3, #T_8dbcd_row22_col4, #T_8dbcd_row23_col0, #T_8dbcd_row23_col1, #T_8dbcd_row23_col2, #T_8dbcd_row23_col3, #T_8dbcd_row23_col4, #T_8dbcd_row24_col0, #T_8dbcd_row24_col1, #T_8dbcd_row24_col2, #T_8dbcd_row24_col3, #T_8dbcd_row24_col4, #T_8dbcd_row25_col0, #T_8dbcd_row25_col1, #T_8dbcd_row25_col2, #T_8dbcd_row25_col3, #T_8dbcd_row25_col4, #T_8dbcd_row26_col0, #T_8dbcd_row26_col1, #T_8dbcd_row26_col2, #T_8dbcd_row26_col3, #T_8dbcd_row26_col4, #T_8dbcd_row27_col0, #T_8dbcd_row27_col1, #T_8dbcd_row27_col2, #T_8dbcd_row27_col3, #T_8dbcd_row27_col4, #T_8dbcd_row28_col0, #T_8dbcd_row28_col1, #T_8dbcd_row28_col2, #T_8dbcd_row28_col3, #T_8dbcd_row28_col4, #T_8dbcd_row29_col0, #T_8dbcd_row29_col1, #T_8dbcd_row29_col2, #T_8dbcd_row29_col3, #T_8dbcd_row29_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_8dbcd">
#   <thead>
#     <tr>
#       <th id="T_8dbcd_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_8dbcd_level0_col1" class="col_heading level0 col1" >Variation</th>
#       <th id="T_8dbcd_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_8dbcd_level0_col3" class="col_heading level0 col3" >Unit</th>
#       <th id="T_8dbcd_level0_col4" class="col_heading level0 col4" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8dbcd_row0_col0" class="data row0 col0" >Completion Rate</td>
#       <td id="T_8dbcd_row0_col1" class="data row0 col1" >Control</td>
#       <td id="T_8dbcd_row0_col2" class="data row0 col2" >49.97</td>
#       <td id="T_8dbcd_row0_col3" class="data row0 col3" >%</td>
#       <td id="T_8dbcd_row0_col4" class="data row0 col4" >Percentage of Control group users who completed the process</td>
#     </tr>
#     <tr>
#       <td id="T_8dbcd_row1_col0" class="data row1 col0" >Completion Rate</td>
#       <td id="T_8dbcd_row1_col1" class="data row1 col1" >Test</td>
#       <td id="T_8dbcd_row1_col2" class="data row1 col2" >52.57</td>
#       <td id="T_8dbcd_row1_col3" class="data row1 col3" >%</td>
#       <td id="T_8dbcd_row1_col4" class="data row1 col4" >Percentage of Test group users who completed the process</td>
#     </tr>
#     <tr>
#       <td id="T_8dbcd_row2_col0" class="data row2 col0" >Strict Completion Rate</td>
#       <td id="T_8dbcd_row2_col1" class="data row2 col1" >Control</td>
#       <td id="T_8dbcd_row2_col2" class="data row2 col2" >49.78</td>
#       <td id="T_8dbcd_row2_col3" class="data row2 col3" >%</td>
#       <td id="T_8dbcd_row2_col4" class="data row2 col4" >Percentage of Control group users who followed strict funnel order and completed it</td>
#     </tr>
#     <tr>
#       <td id="T_8dbcd_row3_col0" class="data row3 col0" >Strict Completion Rate</td>
#       <td id="T_8dbcd_row3_col1" class="data row3 col1" >Test</td>
#       <td id="T_8dbcd_row3_col2" class="data row3 col2" >52.43</td>
#       <td id="T_8dbcd_row3_col3" class="data row3 col3" >%</td>
#       <td id="T_8dbcd_row3_col4" class="data row3 col4" >Percentage of Test group users who followed strict funnel order and completed it</td>
#     </tr>
#     <tr>
#       <td id="T_8dbcd_row4_col0" class="data row4 col0" >Completion Rate Lift</td>
#       <td id="T_8dbcd_row4_col1" class="data row4 col1" >Test vs Control</td>
#       <td id="T_8dbcd_row4_col2" class="data row4 col2" >2.65</td>
#       <td id="T_8dbcd_row4_col3" class="data row4 col3" >pp</td>
#       <td id="T_8dbcd_row4_col4" class="data row4 col4" >Improvement in completion rate for Test compared to Control</td>
#     </tr>
#     <tr>
#       <td id="T_8dbcd_row5_col0" class="data row5 col0" >Step_Back_Errors</td>
#       <td id="T_8dbcd_row5_col1" class="data row5 col1" >Control</td>
#       <td id="T_8dbcd_row5_col2" class="data row5 col2" >5521.0</td>
#       <td id="T_8dbcd_row5_col3" class="data row5 col3" >Count</td>
#       <td id="T_8dbcd_row5_col4" class="data row5 col4" >Total backward step errors in Control group</td>
#     </tr>
#     <tr>
#       <td id="T_8dbcd_row6_col0" class="data row6 col0" >Step_Back_Errors</td>
#       <td id="T_8dbcd_row6_col1" class="data row6 col1" >Test</td>
#       <td id="T_8dbcd_row6_col2" class="data row6 col2" >8138.0</td>
#       <td id="T_8dbcd_row6_col3" class="data row6 col3" >Count</td>
#       <td id="T_8dbcd_row6_col4" class="data row6 col4" >Total backward step errors in Test group</td>
#     </tr>
#     <tr>
#       <td id="T_8dbcd_row7_col0" class="data row7 col0" >Step_Repeat_Errors</td>
#       <td id="T_8dbcd_row7_col1" class="data row7 col1" >Control</td>
#       <td id="T_8dbcd_row7_col2" class="data row7 col2" >7298.0</td>
#       <td id="T_8dbcd_row7_col3" class="data row7 col3" >Count</td>
#       <td id="T_8dbcd_row7_col4" class="data row7 col4" >Total repeated step errors in Control group</td>
#     </tr>
#     <tr>
#       <td id="T_8dbcd_row8_col0" class="data row8 col0" >Step_Repeat_Errors</td>
#       <td id="T_8dbcd_row8_col1" class="data row8 col1" >Test</td>
#       <td id="T_8dbcd_row8_col2" class="data row8 col2" >11139.0</td>
#       <td id="T_8dbcd_row8_col3" class="data row8 col3" >Count</td>
#       <td id="T_8dbcd_row8_col4" class="data row8 col4" >Total repeated step errors in Test group</td>
#     </tr>
#     <tr>
#       <td id="T_8dbcd_row9_col0" class="data row9 col0" >Mean_Step_Time_start</td>
#       <td id="T_8dbcd_row9_col1" class="data row9 col1" >Control</td>
#       <td id="T_8dbcd_row9_col2" class="data row9 col2" >57.46</td>
#       <td id="T_8dbcd_row9_col3" class="data row9 col3" >Seconds</td>
#       <td id="T_8dbcd_row9_col4" class="data row9 col4" >Average duration at start step for Control group</td>
#     </tr>
#     <tr>
#       <td id="T_8dbcd_row10_col0" class="data row10 col0" >Mean_Step_Time_start</td>
#       <td id="T_8dbcd_row10_col1" class="data ro
# ✅ File updated successfully at: ../../data/clean_data_txt/vanguard_kpi_summary_for_tableau_irma_1.csv
# Total metrics now: 36 rows
#    Metric          Variation        Value        Unit    \
# 28  Strict_Lift_CI  Test vs Control  1.78 – 3.44      %
# 29         p_value  Test vs Control       0.0015    NaN
# 30   Calls_6M_Mean          Control          2.1  count
# 31   Calls_6M_Mean             Test          2.4  count
# 32  Logons_6M_Mean          Control          5.3  count
# 33  Logons_6M_Mean             Test          6.0  count
# 34  Strict_Lift_CI  Test vs Control  1.78 – 3.44      %
# 35         p_value  Test vs Control       0.0015
#
#    Description
# 28                  95% confidence interval for the strict completion rate lift
# 29  Two-tailed p-value from proportion test confirming statistical significance
# 30                 Average number of calls in 6 months per user (Control group)
# 31                    Average number of calls in 6 months per user (Test group)
# 32                Average number of logons in 6 months per user (Control group)
# 33                   Average number of logons in 6 months per user (Test group)
# 34                  95% confidence interval for the strict completion rate lift
# 35  Two-tailed p-value from proportion test confirming statistical significance

# %%
import pandas as pd

# === Display Vanguard KPI Summary nicely aligned ===
path = "../../data/clean_data_txt/vanguard_kpi_summary_for_tableau_irma_1.csv"
df = pd.read_csv(path)

# Set visual display options (does not modify the file)
pd.set_option("display.colheader_justify", "left")   # left-align headers
pd.set_option("display.width", None)                 # prevents line wrapping
pd.set_option("display.max_colwidth", None)          # shows full text in Description column

# Show nicely aligned preview
print("📋 Vanguard KPI Summary Preview (clean and aligned):\n")
display(
    df.style
    .set_properties(**{'text-align': 'left'})  # left-align all text
    .hide(axis='index')                        # hide numeric index
)
# Out:
# 📋 Vanguard KPI Summary Preview (clean and aligned):
# <style type="text/css">
# #T_a15c4_row0_col0, #T_a15c4_row0_col1, #T_a15c4_row0_col2, #T_a15c4_row0_col3, #T_a15c4_row0_col4, #T_a15c4_row1_col0, #T_a15c4_row1_col1, #T_a15c4_row1_col2, #T_a15c4_row1_col3, #T_a15c4_row1_col4, #T_a15c4_row2_col0, #T_a15c4_row2_col1, #T_a15c4_row2_col2, #T_a15c4_row2_col3, #T_a15c4_row2_col4, #T_a15c4_row3_col0, #T_a15c4_row3_col1, #T_a15c4_row3_col2, #T_a15c4_row3_col3, #T_a15c4_row3_col4, #T_a15c4_row4_col0, #T_a15c4_row4_col1, #T_a15c4_row4_col2, #T_a15c4_row4_col3, #T_a15c4_row4_col4, #T_a15c4_row5_col0, #T_a15c4_row5_col1, #T_a15c4_row5_col2, #T_a15c4_row5_col3, #T_a15c4_row5_col4, #T_a15c4_row6_col0, #T_a15c4_row6_col1, #T_a15c4_row6_col2, #T_a15c4_row6_col3, #T_a15c4_row6_col4, #T_a15c4_row7_col0, #T_a15c4_row7_col1, #T_a15c4_row7_col2, #T_a15c4_row7_col3, #T_a15c4_row7_col4, #T_a15c4_row8_col0, #T_a15c4_row8_col1, #T_a15c4_row8_col2, #T_a15c4_row8_col3, #T_a15c4_row8_col4, #T_a15c4_row9_col0, #T_a15c4_row9_col1, #T_a15c4_row9_col2, #T_a15c4_row9_col3, #T_a15c4_row9_col4, #T_a15c4_row10_col0, #T_a15c4_row10_col1, #T_a15c4_row10_col2, #T_a15c4_row10_col3, #T_a15c4_row10_col4, #T_a15c4_row11_col0, #T_a15c4_row11_col1, #T_a15c4_row11_col2, #T_a15c4_row11_col3, #T_a15c4_row11_col4, #T_a15c4_row12_col0, #T_a15c4_row12_col1, #T_a15c4_row12_col2, #T_a15c4_row12_col3, #T_a15c4_row12_col4, #T_a15c4_row13_col0, #T_a15c4_row13_col1, #T_a15c4_row13_col2, #T_a15c4_row13_col3, #T_a15c4_row13_col4, #T_a15c4_row14_col0, #T_a15c4_row14_col1, #T_a15c4_row14_col2, #T_a15c4_row14_col3, #T_a15c4_row14_col4, #T_a15c4_row15_col0, #T_a15c4_row15_col1, #T_a15c4_row15_col2, #T_a15c4_row15_col3, #T_a15c4_row15_col4, #T_a15c4_row16_col0, #T_a15c4_row16_col1, #T_a15c4_row16_col2, #T_a15c4_row16_col3, #T_a15c4_row16_col4, #T_a15c4_row17_col0, #T_a15c4_row17_col1, #T_a15c4_row17_col2, #T_a15c4_row17_col3, #T_a15c4_row17_col4, #T_a15c4_row18_col0, #T_a15c4_row18_col1, #T_a15c4_row18_col2, #T_a15c4_row18_col3, #T_a15c4_row18_col4, #T_a15c4_row19_col0, #T_a15c4_row19_col1, #T_a15c4_row19_col2, #T_a15c4_row19_col3, #T_a15c4_row19_col4, #T_a15c4_row20_col0, #T_a15c4_row20_col1, #T_a15c4_row20_col2, #T_a15c4_row20_col3, #T_a15c4_row20_col4, #T_a15c4_row21_col0, #T_a15c4_row21_col1, #T_a15c4_row21_col2, #T_a15c4_row21_col3, #T_a15c4_row21_col4, #T_a15c4_row22_col0, #T_a15c4_row22_col1, #T_a15c4_row22_col2, #T_a15c4_row22_col3, #T_a15c4_row22_col4, #T_a15c4_row23_col0, #T_a15c4_row23_col1, #T_a15c4_row23_col2, #T_a15c4_row23_col3, #T_a15c4_row23_col4, #T_a15c4_row24_col0, #T_a15c4_row24_col1, #T_a15c4_row24_col2, #T_a15c4_row24_col3, #T_a15c4_row24_col4, #T_a15c4_row25_col0, #T_a15c4_row25_col1, #T_a15c4_row25_col2, #T_a15c4_row25_col3, #T_a15c4_row25_col4, #T_a15c4_row26_col0, #T_a15c4_row26_col1, #T_a15c4_row26_col2, #T_a15c4_row26_col3, #T_a15c4_row26_col4, #T_a15c4_row27_col0, #T_a15c4_row27_col1, #T_a15c4_row27_col2, #T_a15c4_row27_col3, #T_a15c4_row27_col4, #T_a15c4_row28_col0, #T_a15c4_row28_col1, #T_a15c4_row28_col2, #T_a15c4_row28_col3, #T_a15c4_row28_col4, #T_a15c4_row29_col0, #T_a15c4_row29_col1, #T_a15c4_row29_col2, #T_a15c4_row29_col3, #T_a15c4_row29_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_a15c4">
#   <thead>
#     <tr>
#       <th id="T_a15c4_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_a15c4_level0_col1" class="col_heading level0 col1" >Variation</th>
#       <th id="T_a15c4_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_a15c4_level0_col3" class="col_heading level0 col3" >Unit</th>
#       <th id="T_a15c4_level0_col4" class="col_heading level0 col4" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a15c4_row0_col0" class="data row0 col0" >Completion Rate</td>
#       <td id="T_a15c4_row0_col1" class="data row0 col1" >Control</td>
#       <td id="T_a15c4_row0_col2" class="data row0 col2" >49.97</td>
#       <td id="T_a15c4_row0_col3" class="data row0 col3" >%</td>
#       <td id="T_a15c4_row0_col4" class="data row0 col4" >Percentage of Control group users who completed the process</td>
#     </tr>
#     <tr>
#       <td id="T_a15c4_row1_col0" class="data row1 col0" >Completion Rate</td>
#       <td id="T_a15c4_row1_col1" class="data row1 col1" >Test</td>
#       <td id="T_a15c4_row1_col2" class="data row1 col2" >52.57</td>
#       <td id="T_a15c4_row1_col3" class="data row1 col3" >%</td>
#       <td id="T_a15c4_row1_col4" class="data row1 col4" >Percentage of Test group users who completed the process</td>
#     </tr>
#     <tr>
#       <td id="T_a15c4_row2_col0" class="data row2 col0" >Strict Completion Rate</td>
#       <td id="T_a15c4_row2_col1" class="data row2 col1" >Control</td>
#       <td id="T_a15c4_row2_col2" class="data row2 col2" >49.78</td>
#       <td id="T_a15c4_row2_col3" class="data row2 col3" >%</td>
#       <td id="T_a15c4_row2_col4" class="data row2 col4" >Percentage of Control group users who followed strict funnel order and completed it</td>
#     </tr>
#     <tr>
#       <td id="T_a15c4_row3_col0" class="data row3 col0" >Strict Completion Rate</td>
#       <td id="T_a15c4_row3_col1" class="data row3 col1" >Test</td>
#       <td id="T_a15c4_row3_col2" class="data row3 col2" >52.43</td>
#       <td id="T_a15c4_row3_col3" class="data row3 col3" >%</td>
#       <td id="T_a15c4_row3_col4" class="data row3 col4" >Percentage of Test group users who followed strict funnel order and completed it</td>
#     </tr>
#     <tr>
#       <td id="T_a15c4_row4_col0" class="data row4 col0" >Completion Rate Lift</td>
#       <td id="T_a15c4_row4_col1" class="data row4 col1" >Test vs Control</td>
#       <td id="T_a15c4_row4_col2" class="data row4 col2" >2.65</td>
#       <td id="T_a15c4_row4_col3" class="data row4 col3" >pp</td>
#       <td id="T_a15c4_row4_col4" class="data row4 col4" >Improvement in completion rate for Test compared to Control</td>
#     </tr>
#     <tr>
#       <td id="T_a15c4_row5_col0" class="data row5 col0" >Step_Back_Errors</td>
#       <td id="T_a15c4_row5_col1" class="data row5 col1" >Control</td>
#       <td id="T_a15c4_row5_col2" class="data row5 col2" >5521.0</td>
#       <td id="T_a15c4_row5_col3" class="data row5 col3" >Count</td>
#       <td id="T_a15c4_row5_col4" class="data row5 col4" >Total backward step errors in Control group</td>
#     </tr>
#     <tr>
#       <td id="T_a15c4_row6_col0" class="data row6 col0" >Step_Back_Errors</td>
#       <td id="T_a15c4_row6_col1" class="data row6 col1" >Test</td>
#       <td id="T_a15c4_row6_col2" class="data row6 col2" >8138.0</td>
#       <td id="T_a15c4_row6_col3" class="data row6 col3" >Count</td>
#       <td id="T_a15c4_row6_col4" class="data row6 col4" >Total backward step errors in Test group</td>
#     </tr>
#     <tr>
#       <td id="T_a15c4_row7_col0" class="data row7 col0" >Step_Repeat_Errors</td>
#       <td id="T_a15c4_row7_col1" class="data row7 col1" >Control</td>
#       <td id="T_a15c4_row7_col2" class="data row7 col2" >7298.0</td>
#       <td id="T_a15c4_row7_col3" class="data row7 col3" >Count</td>
#       <td id="T_a15c4_row7_col4" class="data row7 col4" >Total repeated step errors in Control group</td>
#     </tr>
#     <tr>
#       <td id="T_a15c4_row8_col0" class="data row8 col0" >Step_Repeat_Errors</td>
#       <td id="T_a15c4_row8_col1" class="data row8 col1" >Test</td>
#       <td id="T_a15c4_row8_col2" class="data row8 col2" >11139.0</td>
#       <td id="T_a15c4_row8_col3" class="data row8 col3" >Count</td>
#       <td id="T_a15c4_row8_col4" class="data row8 col4" >Total repeated step errors in Test group</td>
#     </tr>
#     <tr>
#       <td id="T_a15c4_row9_col0" class="data row9 col0" >Mean_Step_Time_start</td>
#       <td id="T_a15c4_row9_col1" class="data row9 col1" >Control</td>
#       <td id="T_a15c4_row9_col2" class="data row9 col2" >57.46</td>
#       <td id="T_a15c4_row9_col3" class="data row9 col3" >Seconds</td>
#       <td id="T_a15c4_row9_col4" class="data row9 col4" >Average duration at start step for Control group</td>
#     </tr>
#     <tr>
#       <td id="T_a15c4_row10_col0" class="data row10 col0" >Mean_Step_Time_start</td>
#       <td id="T_a15c4_row10_col1" class="data ro
